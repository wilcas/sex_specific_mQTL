# %% [markdown]
# # GWAS Curation
# Analyzing just three traits have demonstrated differences in either onset or incidence between males and females has not revealed any obvious differences in heritability explained by marginal and sex-specific mQTLs. As such, I've decided to grab traits from high level categories in the [EFO ontology](https://www.ebi.ac.uk/gwas/docs/ontologyhttps://www.ebi.ac.uk/gwas/docs/ontology) over GWAS in the EBI GWAS catalogue. I am focusing primarily on neurobehavioral traits, citing the following study which found that the majority of traits do not show sex-dependent genetic effects ([Stringer et al 2017](https://doi-org.ezproxy.library.ubc.ca/10.1038/s41598-017-09249-3)).

# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Loading data from the GWAS catalogue
gwas_meta = read_csv("../data/gwas_catalog_all.csv")
head(gwas_meta)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   `DATE ADDED TO CATALOG` = col_date(format = ""),
#   `PUBMED ID` = col_double(),
#   DATE.x = col_date(format = ""),
#   `ASSOCIATION COUNT` = col_double(),
#   `SUMMARY STATS LOCATION` = col_logical(),
#   `SUBMISSION DATE` = col_logical(),
#   `STATISTICAL MODEL` = col_logical(),
#   `BACKGROUND TRAIT` = col_logical(),
#   `MAPPED BACKGROUND TRAIT` = col_logical(),
#   `MAPPED BACKGROUND TRAIT URI` = col_logical(),
#   PUBMEDID = col_double(),
#   DATE.y = col_date(format = ""),
#   `NUMBER OF INDIVDUALS` = col_double()
# )
# See spec(...) for full column specifications.
#   DISEASE/TRAIT                                             STUDY ACCESSION
# 1 &beta;2-Glycoprotein I (&beta;2-GPI) plasma levels        GCST001800
# 2 1,5-anhydroglucitol levels                                GCST004643
# 3 1,5-anhydroglucitol levels                                GCST004643
# 4 1,5-anhydroglucitol levels                                GCST004643
# 5 17-hydroxyprogesterone (17-OHP) levels                    GCST008879
# 6 19,155 disease classifications in UK Biobank (pleiotropy) GCST009606
#   DATE ADDED TO CATALOG PUBMED ID FIRST AUTHOR.x DATE.x
# 1 2013-03-19            23279374  Athanasiadis G 2013-01-02
# 2 2017-09-05            28588231  Li M           2017-06-06
# 3 2017-09-05            28588231  Li M           2017-06-06
# 4 2017-09-05            28588231  Li M           2017-06-06
# 5 2019-10-21            31169883  Pott J         2019-06-06
# 6 2020-02-13            31873298  Cortes A       2019-12-23
#   JOURNAL                 LINK
# 1 J Thromb Haemost        www.ncbi.nlm.nih.gov/pubmed/23279374
# 2 Sci Rep                 www.ncbi.nlm.nih.gov/pubmed/28588231
# 3 Sci Rep                 www.ncbi.nlm.nih.gov/pubmed/28588231
# 4 Sci Rep                 www.ncbi.nlm.nih.gov/pubmed/28588231
# 5 J Clin Endocrinol Metab www.ncbi.nlm.nih.gov/pubmed/31169883
# 6 Nat Genet               www.ncbi.nlm.nih.gov/pubmed/31873298
#   STUDY
# 1 Genetic determinants of plasma β₂-glycoprotein I levels: a genome-wide association study in extended pedigrees from Spain.
# 2 Genome-wide association study of 1,5-anhydroglucitol identifies novel genetic loci linked to glucose metabolism.
# 3 Genome-wide association study of 1,5-anhydroglucitol identifies novel genetic loci linked to glucose metabolism.
# 4 Genome-wide association study of 1,5-anhydroglucitol identifies novel genetic loci linked to glucose metabolism.
# 5 Genetic association study of eight steroid hormones and implications for sexual dimorphism of coronary artery disease.
# 6 Identifying cross-disease components of genetic risk across hospital data in the UK Biobank.
#   INITIAL SAMPLE SIZE                                      ... STAGE
# 1 306 European ancestry individuals                        ... initial
# 2 7,550 European ancestry individuals                      ... initial
# 3 7,550 European ancestry individuals                      ... replication
# 4 7,550 European ancestry individuals                      ... replication
# 5 1,358 European ancestry men, 712 European ancestry women ... initial
# 6 320,644 British ancestry individuals                     ... initial
#   NUMBER OF INDIVDUALS BROAD ANCESTRAL CATEGORY           COUNTRY OF ORIGIN
# 1    306               European                           NR
# 2   7550               European                           NR
# 3   2030               African American or Afro-Caribbean NR
# 4   8790               European                           NR
# 5   2070               European                           NR
# 6 320644               European                           NR
#   COUNTRY OF RECRUITMENT ADDITONAL ANCESTRY DESCRIPTION
# 1 Spain                  NA
# 2 U.S.                   European American
# 3 U.S.                   African American
# 4 Germany, U.K.          NA
# 5 Germany                NA
# 6 U.K.                   NA
#   EFO term                           EFO URI
# 1 glycoprotein measurement           http://www.ebi.ac.uk/efo/EFO_0004555
# 2 1,5 anhydroglucitol measurement    http://www.ebi.ac.uk/efo/EFO_0008009
# 3 1,5 anhydroglucitol measurement    http://www.ebi.ac.uk/efo/EFO_0008009
# 4 1,5 anhydroglucitol measurement    http://www.ebi.ac.uk/efo/EFO_0008009
# 5 17-hydroxyprogesterone measurement http://www.ebi.ac.uk/efo/EFO_0010220
# 6 complex trait                      http://www.ebi.ac.uk/efo/EFO_0010578
#   Parent term       Parent URI
# 1 Other measurement http://www.ebi.ac.uk/efo/EFO_0001444
# 2 Other measurement http://www.ebi.ac.uk/efo/EFO_0001444
# 3 Other measurement http://www.ebi.ac.uk/efo/EFO_0001444
# 4 Other measurement http://www.ebi.ac.uk/efo/EFO_0001444
# 5 Other measurement http://www.ebi.ac.uk/efo/EFO_0001444
# 6 Other trait       http://www.ebi.ac.uk/efo/EFO_0000001

# %%
gwas_meta %>% 
    group_by(`Parent term`) %>% 
    top_n(`Number of Individuals`, 5)
# Out:
# Error in is_scalar_integerish(n): object 'Number of Individuals' not found
# Traceback:
#
# 1. gwas_meta %>% group_by(`Parent term`) %>% top_n(`Number of Individuals`,
#  .     5)
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. top_n(., `Number of Individuals`, 5)
# 10. is_scalar_integerish(n)

# %%
# Out:
# Error in parse(text = x, srcfile = src): <text>:9:9: unexpected symbol
# 8:         M = as.numeric(sbmqtl_methylation[cpg == cur_cpg,-c(1)])
# 9:         Sex
#            ^
# Traceback:
