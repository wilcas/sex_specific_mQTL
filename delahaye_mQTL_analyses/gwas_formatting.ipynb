# %% [markdown]
# # Processing of GWAS summary statistics
# ## Previous attempt: GWAS Curation
# Analyzing just three traits have demonstrated differences in either onset or incidence between males and females has not revealed any obvious differences in heritability explained by marginal and sex-specific mQTLs. As such, I've decided to grab traits from high level categories in the [EFO ontology](https://www.ebi.ac.uk/gwas/docs/ontologyhttps://www.ebi.ac.uk/gwas/docs/ontology) over GWAS in the EBI GWAS catalogue. I am focusing primarily on neurobehavioral traits, citing the following study which found that the majority of traits do not show sex-dependent genetic effects ([Stringer et al 2017](https://doi-org.ezproxy.library.ubc.ca/10.1038/s41598-017-09249-3)).

# %%
import pandas as pd
# %load_ext rpy2.ipython
# %R library(tidyverse)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# <rpy2.robjects.vectors.StrVector object at 0x2aaaae35d4c0> [RTYPES.STRSXP]
# R classes: ('character',)
# ['forcats', 'stringr', 'dplyr', 'purrr', ..., 'utils', 'datasets', 'methods', 'base']

# %%
# Loading data from the GWAS catalogue
gwas_meta = pd.read_csv("../data/gwas_catalog_all.csv")
gwas_meta.head()
# Out:
#                                        DISEASE/TRAIT STUDY ACCESSION  \
# 0  &beta;2-Glycoprotein I (&beta;2-GPI) plasma le...      GCST001800
# 1                         1,5-anhydroglucitol levels      GCST004643
# 2                         1,5-anhydroglucitol levels      GCST004643
# 3                         1,5-anhydroglucitol levels      GCST004643
# 4             17-hydroxyprogesterone (17-OHP) levels      GCST008879
#
#   DATE ADDED TO CATALOG  PUBMED ID  FIRST AUTHOR.x      DATE.x  \
# 0            2013-03-19   23279374  Athanasiadis G  2013-01-02
# 1            2017-09-05   28588231            Li M  2017-06-06
# 2            2017-09-05   28588231            Li M  2017-06-06
# 3            2017-09-05   28588231            Li M  2017-06-06
# 4            2019-10-21   31169883          Pott J  2019-06-06
#
#                    JOURNAL                                  LINK  \
# 0         J Thromb Haemost  www.ncbi.nlm.nih.gov/pubmed/23279374
# 1                  Sci Rep  www.ncbi.nlm.nih.gov/pubmed/28588231
# 2                  Sci Rep  www.ncbi.nlm.nih.gov/pubmed/28588231
# 3                  Sci Rep  www.ncbi.nlm.nih.gov/pubmed/28588231
# 4  J Clin Endocrinol Metab  www.ncbi.nlm.nih.gov/pubmed/31169883
#
#                                                STUDY  \
# 0  Genetic determinants of plasma β₂-glycoprotein...
# 1  Genome-wide association study of 1,5-anhydrogl...
# 2  Genome-wide association study of 1,5-anhydrogl...
# 3  Genome-wide association study of 1,5-anhydrogl...
# 4  Genetic association study of eight steroid hor...
#
#                                  INITIAL SAMPLE SIZE  ...        STAGE  \
# 0                  306 European ancestry individuals  ...      initial
# 1                7,550 European ancestry individuals  ...      initial
# 2                7,550 European ancestry individuals  ...  replication
# 3                7,550 European ancestry individuals  ...  replication
# 4  1,358 European ancestry men, 712 European ance...  ...      initial
#
#   NUMBER OF INDIVDUALS            BROAD ANCESTRAL CATEGORY COUNTRY OF ORIGIN  \
# 0                306.0                            European                NR
# 1               7550.0                            European                NR
# 2               2030.0  African American or Afro-Caribbean                NR
# 3               8790.0                            European                NR
# 4               2070.0                            European                NR
#
#   COUNTRY OF RECRUITMENT ADDITONAL ANCESTRY DESCRIPTION  \
# 0                  Spain                            NaN
# 1                   U.S.              European American
# 2                   U.S.               African American
# 3          Germany, U.K.                            NaN
# 4                Germany                            NaN
#
#                              EFO term                               EFO URI  \
# 0            glycoprotein measurement  http://www.ebi.ac.uk/efo/EFO_0004555
# 1     1,5 anhydroglucitol measurement  http://www.ebi.ac.uk/efo/EFO_0008009
# 2     1,5 anhydroglucitol measurement  http://www.ebi.ac.uk/efo/EFO_0008009
# 3     1,5 anhydroglucitol measurement  http://www.ebi.ac.uk/efo/EFO_0008009
# 4  17-hydroxyprogesterone measurement  http://www.ebi.ac.uk/efo/EFO_0010220
#
#          Parent term                            Parent URI
# 0  Other measurement  http://www.ebi.ac.uk/efo/EFO_0001444
# 1  Other measurement  http://www.ebi.ac.uk/efo/EFO_0001444
# 2  Other measurement  http://www.ebi.ac.uk/efo/EFO_0001444
# 3  Other measurement  http://www.ebi.ac.uk/efo/EFO_0001444
# 4  Other measurement  http://www.ebi.ac.uk/efo/EFO_0001444
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Uniform formatting with `munge_sumstats.py`

# %%
# %%bash
# for f in ../../tmp_GWAS/pgc_sumstats/*; do
#     echo $f
#     zcat $f | head -n 2
# done
# Out:
# ../../tmp_GWAS/pgc_sumstats/adhd_jul2017.gz
# CHR	SNP	BP	A1	A2	INFO	OR	SE	P
# 1	rs202152658	751343	A	T	0.884	1.03118	0.0221	0.1654
# ../../tmp_GWAS/pgc_sumstats/anxiety.meta.full.cc.tbl.gz
# SNPID	CHR	BP	Allele1	Allele2	Freq1	Effect	StdErr	P.value	TotalN
# rs1000033	1	226580387	t	g	0.8266	-0.0574	0.0348	0.09867	17310
# ../../tmp_GWAS/pgc_sumstats/anxiety.meta.full.fs.tbl.gz
# SNPID	CHR	BP	Allele1	Allele2	Freq1	Effect	StdErr	P.value	TotalN
# rs1000033	1	226580387	t	g	0.824	-0.0057	0.0058	0.3288	18186
# ../../tmp_GWAS/pgc_sumstats/AUDIT_UKB_2018_AJP.txt.gz
# chr rsid a_0 a_1 info beta_T se_T p_T beta_C se_C p_C beta_P se_P p_P N
# 1 1:10000179_AAAAAAAC_A AAAAAAAC A 0.985768 -0.0023263 0.0087656 0.790715040934701 0.0024046 0.0080078 0.763958909282397 -0.013933 0.0076296 0.0678265926015363 121568
# ../../tmp_GWAS/pgc_sumstats/Cannabis_ICC_23andmetop_UKB_het.txt.gz
# CHR	SNP	BP	A1	A2	FRQ	BETA	SE	Z	P	Direction	HetISq	HetDf	HetPVa	Nca	Nco	Neff
# 3	rs2875907	85518580	a	g	0.3524	0.0712	0.0086	8.27907	9.381e-17	+++	0	2	0.5839	53179	131586	151493
# ../../tmp_GWAS/pgc_sumstats/iPSYCH-PGC_ASD_Nov2017.gz
# CHR	SNP	BP	A1	A2	INFO	OR	SE	P
# 8	rs62513865	101592213	T	C	0.949	1.00652	0.027	0.8086
# ../../tmp_GWAS/pgc_sumstats/ocd_aug2017.gz
# CHR	SNP	BP	A1	A2	INFO	OR	SE	P
# 1	rs141242758	734349	T	C	0.6683	1.07358	0.1088	0.5144
# ../../tmp_GWAS/pgc_sumstats/PGC3_SCZ_wave3_public.v2.tsv.gz
# CHR	SNP	BP	A1	A2	FRQ_A_67390	FRQ_U_94015	INFO	OR	SE	P	ngt	Direction	HetISqt	HetDf	HetPVa	Nca	Nco	Neff
# 8	rs62513865	101592213	C	T	0.932	0.928	0.954	1.01349	0.0171	0.4319	0	-?-+--+++???-+--+-+-++-++-+?????+++-+--+-??++-----++--------++++++-+-?+-+-++---++--+--++++	9.0	77	0.259	55085	78957	60448.13
# ../../tmp_GWAS/pgc_sumstats/pgc_adhd_females.gz
# SNP CHR BP A1 A2 Effect SE P
# rs2326918 6 130840091 A G -0.0472 0.0353 0.1818
# ../../tmp_GWAS/pgc_sumstats/pgc_adhd_males.gz
# SNP CHR BP A1 A2 Effect SE P
# rs2326918 6 130840091 A G -0.0103 0.0245 0.6731
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.afr_discovery.aug2018_release.txt.gz
# CHR SNP BP A1 A2 Z P Weight
# 1 rs111906919:16160196:T:C 16160196 T C -0.757 0.4488 1978.10
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.afr_unrelated.aug2018_release.txt.gz
# CHR SNP BP A1 A2 Z P Weight
# 1 rs111906919:16160196:T:C 16160196 T C -0.757 0.4488 1978.10
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.afr_unrel_genotyped.aug2018_release.txt.gz
# CHR SNP BP A1 A2 INFO OR SE P Neff
# 8 rs73696507 105231413 C T 0.979 1.02798 0.0731 0.7062 4587.06
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.discovery.aug2018_release.txt.gz
# CHR SNP BP A1 A2 Z P Weight
# 1 rs370839278:194108898:ACAAGGGTG:A 194108898 A ACAAGGGTG 0.833 0.4049 4947.36
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.eur_discovery.aug2018_release.txt.gz
# CHR SNP BP A1 A2 Z P Weight
# 1 rs10799799:23973601:G:T 23973601 T G -0.012 0.9904 24810.32
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.eur_unrelated.aug2018_release.txt.gz
# CHR SNP BP A1 A2 Z P Weight
# 1 rs10799799:23973601:G:T 23973601 T G -0.190 0.8495 21857.28
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.eur_unrel_genotyped.aug2018_release.txt.gz
# CHR SNP BP A1 A2 INFO OR SE P Neff
# 8 rs79643588 106973048 A G 0.995 0.97346 0.0381 0.4797 17852.9
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.trans_fe_unrel_geno.aug2018_release.txt.gz
# CHR SNP BP A1 A2 INFO BETA SE P Neff
# 1 rs12034030 68677760 T C 0.986 0.0242563 0.0270064 0.369097 20293.6
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.trans_mantra_unrel_geno.aug2018_release.txt.gz
# CHR SNP BP A1 A2 INFO Log10BF Neff
# 1 rs12034030 68677760 T C 0.986 -0.42345 20293.6
# ../../tmp_GWAS/pgc_sumstats/pgc_alcdep.trans_re2_unrel_geno.aug2018_release.txt.gz
# CHR SNP BP A1 A2 INFO STAT1_RE2 STAT2_RE2 P Neff
# 1 rs12034030 68677760 T C 0.986 0.806703 0.00000 0.402449 20293.6
# ../../tmp_GWAS/pgc_sumstats/pgcAN2.2019-07.vcf.tsv.gz
# ##fileFormat=PGCsumstatsVCFv1.0
# ##CAVEAT EMPTOR: ALWAYS CHECK FOR NEWER VERSION
# ../../tmp_GWAS/pgc_sumstats/pgc_bip_2018.gz
# CHR	SNP	BP	A1	A2	FRQ_A_20352	FRQ_U_31358	INFO	OR	SE	P	ngt	Direction	HetISqt	HetDf	HetPVa	Nca	Nco	Neff
# 10	rs185339560	2392426	T	C	0.00935	0.0081	0.67	1.16813	0.0923	0.09239	0	+--+++++--+?++--+-+-?++++++++--+	0.0	29	0.6096	19294	29909	22093.09
# ../../tmp_GWAS/pgc_sumstats/pgc.cross.full.2013-03.txt.gz
# snpid hg18chr bp a1 a2 or se pval info ngt CEUaf
# rs3131972	1	742584	A	G	1.047	0.0361	0.2032	0.774	0	0.16055
# ../../tmp_GWAS/pgc_sumstats/pgc.ed.freeze1.summarystatistics.July2017.txt.gz
# CHR	SNP	BP	A1	A2	INFO	OR	SE	P	ngt
# 1	chr1:100012367	100012367	T	C	0.842	3.84164	1.5	0.3694	0
# ../../tmp_GWAS/pgc_sumstats/PGC_UKB_depression_genome-wide.txt.gz
# MarkerName A1 A2 Freq LogOR StdErrLogOR P
# rs2326918 a g 0.8452 0.0106 0.006 0.07561
# ../../tmp_GWAS/pgc_sumstats/pts_all_freeze2_females.results.gz
# CHR	SNP	BP	A1	A2	FRQ_A_16845	FRQ_U_80105	INFO	OR	SE	P	ngt	Direction	HetISqt	HetDf	HetPVa	Nca	Nco	Neff
# 4	rs34341799	115156932	G	GA	0.2726	0.2504	0.997508	1.12547	0.0222	9.698e-08	0	++++-++-+++++-+?-++++?--+++-++-+++++-+++++	0.0	39	0.9923	9795	15143	22188
# ../../tmp_GWAS/pgc_sumstats/pts_all_freeze2_males.results.gz
# CHR	SNP	BP	A1	A2	FRQ_A_12082	FRQ_U_82978	INFO	OR	SE	P	ngt	Direction	HetISqt	HetDf	HetPVa	Nca	Nco	Neff
# 12	rs71439306	132944639	A	C	0.0327	0.0237	0.753576	1.54326	0.0821	1.273e-07	0	+?++-?+++++?++?????--?-+++-+++??????????????-+-+--?	0.0	26	0.7858	5202	21351	14540.4
# ../../tmp_GWAS/pgc_sumstats/pts_all_freeze2_overall.results.gz
# CHR	SNP	BP	A1	A2	FRQ_A_29529	FRQ_U_166145	INFO	OR	SE	P	ngt	Direction	HetISqt	HetDf	HetPVa	Nca	Nco	Neff
# 6	rs9459288m	157790612	T	C	0.7144	0.7312	0.862271	0.915212	0.0170	1.804e-07	0	--+---?-+---++-------+?+-----++-----?++++++---+-+++-+++++-+++++---++--	15.8	66	0.1415	18424	48144	46094.3
# ../../tmp_GWAS/pgc_sumstats/tag.cpd.tbl.gz
# CHR	SNP	BP	A1	A2	FRQ_A	FRQ_U	INFO	OR	SE	P
# 1	rs12565286	711153	C	G	0.0434	0.0434	1	-0.4029	0.5634	0.4745
# ../../tmp_GWAS/pgc_sumstats/TS_Oct2018.gz
# SNP CHR BP A1 A2 INFO OR SE P
# rs2326918 6 130840091 A G 0.9858 0.965412 0.0349 0.3139

# %% [markdown]
# With the exception of the vcf.tsv formatted files, it appears that the formatting of these summary statistics is fairly uniform. Let's see if we can just run munge_sumstats through all of these files:

# %%
# %%bash
# source /home/wcasazza/miniconda3/bin/activate
# conda activate ldsc
# cd /scratch/st-dennisjk-1/wcasazza/tmp_GWAS/
# echo "" > missed_files.txt
# for f in pgc_sumstats/*.gz; do
#     out_f=${f%.*}
#     skip=""
#     if [[ ! -f "pgc_formatted_sumstats/${out_f##*/}.sumstats.gz" ]]; then
#         cmd="/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py"
#         cmd+=" --sumstats ${f}"
#         cmd+=" --out pgc_formatted_sumstats/${out_f##*/}"
#         for arg in $(zgrep -v "^#" ${f} | head -n 1 | tr -d '\r\n'); do
#             case ${arg} in
#                 "TotalN")
#                     cmd+=" --N-col TotalN"
#                 ;;
#                 "Neff")
#                     cmd+=" --N-col Neff"
#                 ;;
#                 "Nca")
#                     cmd+=" --N-cas-col Nca"
#                 ;;
#                 "NCAS")
#                     cmd+=" --N-cas-col NCAS"
#                 ;;
#                 "NCON")
#                     cmd+=" --N-con-col NCON"
#                 ;;
#                 "Nco")
#                     cmd+=" --N-con-col Nco"
#                 ;;
#                 "Z")
#                     cmd+=" --signed-sumstats Z,0"
#                     break
#                 ;;
#                 "BETA")
#                     cmd+=" --signed-sumstats BETA,0"
#                 ;;
#                 "LogOR")
#                     cmd+=" --signed-sumstats LogOR,0"
#                 ;;
#                 "Log10BF")
#                     cmd+=" --signed-sumstats Log10BF,0"
#                 ;;
#                 "REF")
#                     cmd+=" --a1 REF"
#                 ;;
#                 "ALT")
#                     cmd+=" --a2 ALT"
#                 ;;
#                 "ID")
#                     cmd+=" --snp ID"
#                 ;;
#                 *)
#                     echo "${arg} ignored."
#                 ;;
#             esac
#         done
#             # Datasets without N column and other special cases
#             case "${out_f##*/}" in
#                 "adhd_jul2017")
#                     cmd+=" --N-cas 20183"
#                     cmd+=" --N-con 35191"
#                 ;;
#                 "AUDIT_UKB_2018_AJP.txt") #Focus on TOTAL Audit score only
#                     cmd+=" --signed-sumstats beta_T,0"
#                     cmd+=" --p p_T"
#                     cmd+=" --a1 a_0"
#                     cmd+=" --a2 a_1"
#                 ;;
#                 "iPSYCH-PGC_ASD_Nov2017")
#                     cmd+=" --N-cas 18381"
#                     cmd+=" --N-con 27969"
#                 ;;
#                 "ocd_aug2017")
#                     cmd+=" --N-cas 2688"
#                     cmd+=" --N-con 7037"
#                 ;;
#                 "pgc_adhd_females")
#                     cmd+=" --N-cas 4945"
#                     cmd+=" --N-con 16246"
#                 ;;
#                 "pgc_adhd_males")
#                     cmd+=" --N-cas 14154"
#                     cmd+=" --N-con 17948"
#                 ;;
#                 "pgc_alcdep.trans_re2_unrel_geno.aug2018_release.txt")
#                     skip=1
#                 ;;
#                 "pgc_alcdep.trans_mantra_unrel_geno.aug2018_release.txt")
#                     skip=1
#                 ;;
#                 "pgc.cross.full.2013-03.txt")
#                     cmd+=" --N-cas 33332"
#                     cmd+=" --N-con 27888"
#                 ;;
#                 "PGC_UKB_depression_genome-wide.txt")
#                     cmd+=" --N-cas 246363"
#                     cmd+=" --N-con 561190"
#                 ;;
#                 "tag.cpd.tbl")
#                     cmd+=" --N 74053"
#                     cmd+=" --signed-sumstats OR,0"
#                 ;;
#                 "TS_Oct2018")
#                     cmd+=" --N-cas 4819"
#                     cmd+=" --N-con 9788"
#                 ;;
#                 *)
#                     echo "Header of ${f} was parsed."
#                 ;;
#             esac
#         if [[ ! ${skip} ]]; then
#             eval $cmd
#         fi
#     fi
# done
# Out:
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# chr ignored.
# rsid ignored.
# a_0 ignored.
# a_1 ignored.
# info ignored.
# beta_T ignored.
# se_T ignored.
# p_T ignored.
# beta_C ignored.
# se_C ignored.
# p_C ignored.
# beta_P ignored.
# se_P ignored.
# p_P ignored.
# N ignored.
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# SNP ignored.
# CHR ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# Effect ignored.
# SE ignored.
# P ignored.
# SNP ignored.
# CHR ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# Effect ignored.
# SE ignored.
# P ignored.
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# Header of pgc_sumstats/pgc_alcdep.trans_mantra_unrel_geno.aug2018_release.txt.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --signed-sumstats Log10BF,0 \
# --out pgc_formatted_sumstats/pgc_alcdep.trans_mantra_unrel_geno.aug2018_release.txt \
# --N-col Neff \
# --sumstats pgc_sumstats/pgc_alcdep.trans_mantra_unrel_geno.aug2018_release.txt.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 627, in munge_sumstats
#     raise ValueError('Could not find {C} column.'.format(C=c))
# ValueError: Could not find P column.
#
#
# Conversion finished at Tue Mar 23 11:07:30 2021
# Total time elapsed: 0.11s
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# STAT1_RE2 ignored.
# STAT2_RE2 ignored.
# P ignored.
# CHROM ignored.
# POS ignored.
# REF ignored.
# ALT ignored.
# SE ignored.
# PVAL ignored.
# NGT ignored.
# IMPINFO ignored.
# NEFFDIV2 ignored.
# NCON ignored.
# DIRE ignored.
# Header of pgc_sumstats/pgcAN2.2019-07.vcf.tsv.gz was parsed.
# snpid ignored.
# hg18chr ignored.
# bp ignored.
# a1 ignored.
# a2 ignored.
# or ignored.
# se ignored.
# pval ignored.
# info ignored.
# ngt ignored.
# CEUaf ignored.
# Header of pgc_sumstats/pgc.cross.full.2013-03.txt.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --out pgc_formatted_sumstats/pgc.cross.full.2013-03.txt \
# --sumstats pgc_sumstats/pgc.cross.full.2013-03.txt.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
#
#
# Conversion finished at Tue Mar 23 11:07:39 2021
# Total time elapsed: 0.02s
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# ngt ignored.
# Header of pgc_sumstats/pgc.ed.freeze1.summarystatistics.July2017.txt.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --out pgc_formatted_sumstats/pgc.ed.freeze1.summarystatistics.July2017.txt \
# --sumstats pgc_sumstats/pgc.ed.freeze1.summarystatistics.July2017.txt.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
#
#
# Conversion finished at Tue Mar 23 11:07:42 2021
# Total time elapsed: 0.01s
# MarkerName ignored.
# A1 ignored.
# A2 ignored.
# Freq ignored.
# StdErrLogOR ignored.
# P ignored.
# Header of pgc_sumstats/PGC_UKB_depression_genome-wide.txt.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --signed-sumstats LogOR,0 \
# --out pgc_formatted_sumstats/PGC_UKB_depression_genome-wide.txt \
# --sumstats pgc_sumstats/PGC_UKB_depression_genome-wide.txt.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
#
#
# Conversion finished at Tue Mar 23 11:07:44 2021
# Total time elapsed: 0.01s
# CHR ignored.
# SNP ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# FRQ_A ignored.
# FRQ_U ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# Header of pgc_sumstats/tag.cpd.tbl.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --out pgc_formatted_sumstats/tag.cpd.tbl \
# --sumstats pgc_sumstats/tag.cpd.tbl.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
#
#
# Conversion finished at Tue Mar 23 11:07:47 2021
# Total time elapsed: 0.01s
# SNP ignored.
# CHR ignored.
# BP ignored.
# A1 ignored.
# A2 ignored.
# INFO ignored.
# OR ignored.
# SE ignored.
# P ignored.
# Header of pgc_sumstats/TS_Oct2018.gz was parsed.
# *********************************************************************
# * LD Score Regression (LDSC)
# * Version 1.0.1
# * (C) 2014-2019 Brendan Bulik-Sullivan and Hilary Finucane
# * Broad Institute of MIT and Harvard / MIT Department of Mathematics
# * GNU General Public License v3
# *********************************************************************
# Call:
# ./munge_sumstats.py \
# --out pgc_formatted_sumstats/TS_Oct2018 \
# --sumstats pgc_sumstats/TS_Oct2018.gz
#
#
# ERROR converting summary statistics:
#
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
#
#
# Conversion finished at Tue Mar 23 11:07:51 2021
# Total time elapsed: 0.01s
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: argument --N: invalid float value: 'MISSING'
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: unrecognized arguments: README FOR SUMSTAT LABEL MEANING
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: argument --N: invalid float value: 'MISSING'
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: argument --N: invalid float value: 'MISSING'
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: argument --N: invalid float value: 'MISSING'
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: argument --N: invalid float value: 'MISSING'
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 627, in munge_sumstats
#     raise ValueError('Could not find {C} column.'.format(C=c))
# ValueError: Could not find P column.
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: unrecognized arguments: README FOR SUMSTAT LABEL MEANING
# usage: munge_sumstats.py [-h] [--sumstats SUMSTATS] [--N N] [--N-cas N_CAS]
#                          [--N-con N_CON] [--out OUT] [--info-min INFO_MIN]
#                          [--maf-min MAF_MIN] [--daner] [--daner-n]
#                          [--no-alleles] [--merge-alleles MERGE_ALLELES]
#                          [--n-min N_MIN] [--chunksize CHUNKSIZE] [--snp SNP]
#                          [--N-col N_COL] [--N-cas-col N_CAS_COL]
#                          [--N-con-col N_CON_COL] [--a1 A1] [--a2 A2] [--p P]
#                          [--frq FRQ] [--signed-sumstats SIGNED_SUMSTATS]
#                          [--info INFO] [--info-list INFO_LIST]
#                          [--nstudy NSTUDY] [--nstudy-min NSTUDY_MIN]
#                          [--ignore IGNORE] [--a1-inc] [--keep-maf]
# munge_sumstats.py: error: unrecognized arguments: --snp-col ID
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
# Traceback (most recent call last):
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 745, in <module>
#     munge_sumstats(parser.parse_args(), p=True)
#   File "/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py", line 643, in munge_sumstats
#     raise ValueError('Could not determine N.')
# ValueError: Could not determine N.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-90aa387d438c> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', 'source /home/wcasazza/miniconda3/bin/activate\nconda activate ldsc\ncd /scratch/st-dennisjk-1/wcasazza/tmp_GWAS/\necho "" > missed_files.txt\nfor f in pgc_sumstats/*.gz; do\n    out_f=${f%.*}\n    if [[ ! -f "pgc_formatted_sumstats/${out_f##*/}.sumstats.gz" ]]; then\n        cmd="/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py"\n        cmd+=" --sumstats ${f}"\n        cmd+=" --out pgc_formatted_sumstats/${out_f##*/}"\n        for arg in $(zgrep -v "^#" ${f} | head -n 1 | tr -d \'\\r\\n\'); do\n            case ${arg} in\n                "TotalN")\n                    cmd+=" --N-col TotalN"\n                ;;\n                "Neff")\n                    cmd+=" --N-col Neff"\n                ;;\n                "Nca")\n                    cmd+=" --N-cas-col Nca"\n                ;;\n                "NCAS")\n                    cmd+=" --N-cas-col NCAS"\n                ;;\n                "Nco")\n                    cmd+=" --N-con-col Nco"\n                ;;\n                "Z")\n                    cmd+=" --signed-sumstats Z,0"\n                    break\n                ;;\n                "BETA")\n                    cmd+=" --signed-sumstats BETA,0"\n                ;;\n                "LogOR")\n                    cmd+=" --signed-sumstats LogOR,0"\n                ;;\n                "Log10BF")\n                    cmd+=" --signed-sumstats Log10BF,0"\n                ;;\n                "ID")\n                    cmd+=" --snp-col ID"\n                ;;\n                *)\n                    echo "${arg} ignored."\n                ;;\n            esac\n        done\n            # Datasets without N column and other special cases\n            case "${out_f##*/}" in\n                "adhd_jul2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "AUDIT_UKB_2018_AJP.txt")\n                    cmd+="CHECK README FOR SUMSTAT LABEL MEANING"\n                ;;\n                "iPSYCH-PGC_ASD_Nov2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "ocd_aug2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_adhd_females")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_adhd_males")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_alcdep.trans_re2_unrel_geno.aug2018_release.txt")\n                    cmd+="CHECK README FOR SUMSTAT LABEL MEANING"\n                ;;\n                *)\n                    echo "Header of ${f} was parsed."\n                ;;\n            esac\n        eval $cmd\n    fi\ndone\n')
#
# /home/wcasazza/miniconda3/envs/big_data/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2397             with self.builtin_trap:
#    2398                 args = (magic_arg_s, cell)
# -> 2399                 result = fn(*args, **kwargs)
#    2400             return result
#    2401
#
# /home/wcasazza/miniconda3/envs/big_data/lib/python3.8/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /home/wcasazza/miniconda3/envs/big_data/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /home/wcasazza/miniconda3/envs/big_data/lib/python3.8/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'source /home/wcasazza/miniconda3/bin/activate\nconda activate ldsc\ncd /scratch/st-dennisjk-1/wcasazza/tmp_GWAS/\necho "" > missed_files.txt\nfor f in pgc_sumstats/*.gz; do\n    out_f=${f%.*}\n    if [[ ! -f "pgc_formatted_sumstats/${out_f##*/}.sumstats.gz" ]]; then\n        cmd="/arc/project/st-dennisjk-1/software/ldsc/munge_sumstats.py"\n        cmd+=" --sumstats ${f}"\n        cmd+=" --out pgc_formatted_sumstats/${out_f##*/}"\n        for arg in $(zgrep -v "^#" ${f} | head -n 1 | tr -d \'\\r\\n\'); do\n            case ${arg} in\n                "TotalN")\n                    cmd+=" --N-col TotalN"\n                ;;\n                "Neff")\n                    cmd+=" --N-col Neff"\n                ;;\n                "Nca")\n                    cmd+=" --N-cas-col Nca"\n                ;;\n                "NCAS")\n                    cmd+=" --N-cas-col NCAS"\n                ;;\n                "Nco")\n                    cmd+=" --N-con-col Nco"\n                ;;\n                "Z")\n                    cmd+=" --signed-sumstats Z,0"\n                    break\n                ;;\n                "BETA")\n                    cmd+=" --signed-sumstats BETA,0"\n                ;;\n                "LogOR")\n                    cmd+=" --signed-sumstats LogOR,0"\n                ;;\n                "Log10BF")\n                    cmd+=" --signed-sumstats Log10BF,0"\n                ;;\n                "ID")\n                    cmd+=" --snp-col ID"\n                ;;\n                *)\n                    echo "${arg} ignored."\n                ;;\n            esac\n        done\n            # Datasets without N column and other special cases\n            case "${out_f##*/}" in\n                "adhd_jul2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "AUDIT_UKB_2018_AJP.txt")\n                    cmd+="CHECK README FOR SUMSTAT LABEL MEANING"\n                ;;\n                "iPSYCH-PGC_ASD_Nov2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "ocd_aug2017")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_adhd_females")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_adhd_males")\n                    cmd+=" --N MISSING"\n                ;;\n                "pgc_alcdep.trans_re2_unrel_geno.aug2018_release.txt")\n                    cmd+="CHECK README FOR SUMSTAT LABEL MEANING"\n                ;;\n                *)\n                    echo "Header of ${f} was parsed."\n                ;;\n            esac\n        eval $cmd\n    fi\ndone\n'' returned non-zero exit status 1.

# %%
# %%bash
# gwas_out=""
# for f in /scratch/st-dennisjk-1/wcasazza/tmp_GWAS/pgc_formatted_sumstats/*.gz; do
#     tmp="${f/.sumstats.gz/}"
#     tmp="${tmp##*/}"
#     gwas_out+=" $tmp"
# done
# echo $gwas_out
# ls /scratch/st-dennisjk-1/wcasazza/tmp_GWAS/pgc_formatted_sumstats/*.gz | wc -l
# Out:
# adhd_jul2017 anxiety.meta.full.cc.tbl anxiety.meta.full.fs.tbl AUDIT_UKB_2018_AJP.txt Cannabis_ICC_23andmetop_UKB_het.txt iPSYCH-PGC_ASD_Nov2017 ocd_aug2017 PGC3_SCZ_wave3_public.v2.tsv pgc_adhd_females pgc_adhd_males pgc_alcdep.afr_discovery.aug2018_release.txt pgc_alcdep.afr_unrelated.aug2018_release.txt pgc_alcdep.afr_unrel_genotyped.aug2018_release.txt pgc_alcdep.discovery.aug2018_release.txt pgc_alcdep.eur_discovery.aug2018_release.txt pgc_alcdep.eur_unrelated.aug2018_release.txt pgc_alcdep.eur_unrel_genotyped.aug2018_release.txt pgc_alcdep.trans_fe_unrel_geno.aug2018_release.txt pgcAN2.2019-07.vcf.tsv pgc_bip_2018 pgc.cross.full.2013-03.txt PGC_UKB_depression_genome-wide.txt pts_all_freeze2_females.results pts_all_freeze2_males.results pts_all_freeze2_overall.results TS_Oct2018
# 26

# %%
26* 3 * 2
# Out:
# 156
